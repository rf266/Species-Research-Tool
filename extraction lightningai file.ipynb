# %%
import pickle
import os
import nest_asyncio

from llama_index.core.extractors import TitleExtractor, KeywordExtractor

with open("nodes.pkl", "rb") as f:
    nodes = pickle.load(f)


nest_asyncio.apply()

# %%
#from llama_index.llms.openrouter import OpenRouter
#from llama_index.llms.fireworks import Fireworks
#from llama_index.llms.cerebras import Cerebras
from llama_index.llms.huggingface import HuggingFaceLLM
import os
from dotenv import load_dotenv
from transformers import AutoModelForCausalLM, BitsAndBytesConfig

load_dotenv()
#api1 = os.getenv("OR_API_KEY")
#model = OpenRouter(model="qwen/qwen3.7-plus", api_key =api1 )
#api2 = os.getenv("CEREBRAS_API_KEY")

quants = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype="float16",
)

model2 = HuggingFaceLLM(model_name="Qwen/Qwen2.5-3B-Instruct", tokenizer_name="Qwen/Qwen2.5-3B-Instruct",
                        model_kwargs={'quantization_config':quants}, device_map='auto',
                        context_window=3000,max_new_tokens=16)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
keywords_extract = KeywordExtractor(keywords=5, llm=model2)
from llama_index.extractors.entity import EntityExtractor

from llama_index.core.ingestion import IngestionPipeline
entities = EntityExtractor(prediction_threshold=0.7, label_entities= True, device='cuda')
pipeline = IngestionPipeline(transformations=[keywords_extract, entities])

for i in range(0, len(nodes), 10):
  if i <9530:
    now = nodes[i:i+10]
  else:
    now = nodes[i:]

  print(f"processing {i} to next")
  extracted = pipeline.run(
    documents=now,
    show_progress=True)
  prevs=[]
  if os.path.getsize("/teamspace/studios/this_studio/extracts.pkl") == 0:
    prevs = []
  else:
    with open("extracts.pkl", "rb") as f: 
      prevs = pickle.load(f) 
  with open("extracts.pkl", "wb") as f: 

    pickle.dump(prevs + extracted, f)
# Out:
# processing 0 to next
# ...
# Extracting entities:   0%|          | 0/10 [00:00<?, ?it/s]
# processing 10 to next
# ...
# Extracting entities:   0%|          | 0/10 [00:00<?, ?it/s]
# processing 20 to next
# ...
# Extracting entities:   0%|          | 0/10 [00:00<?, ?it/s]
# processing 30 to next
# ...
# Extracting entities:   0%|          | 0/10 [00:00<?, ?it/s]
# processing 40 to next
# ...
# Extracting entities:   0%|          | 0/10 [00:00<?, ?it/s]
# processing 50 to next
# ...
# Extracting entities:   0%|          | 0/10 [00:00<?, ?it/s]
# processing 60 to next
# ...
# Extracting entities:   0%|          | 0/10 [00:00<?, ?it/s]
# processing 70 to next
# ...
# Extracting entities:   0%|          | 0/10 [00:00<?, ?it/s]
# processing 80 to next
# ...
# Extracting entities:   0%|          | 0/10 [00:00<?, ?it/s]
# processing 90 to next
# ...
# Extracting entities:   0%|          | 0/10 [00:00<?, ?it/s]
# processing 100 to next
# ...
# Extracting entities:   0%|          | 0/10 [00:00<?, ?it/s]
# processing 110 to next
# ...
